# %%
import collections
collections.Sequence = collections.abc.Sequence
collections.MutableMapping = collections.abc.MutableMapping
import skrf as rf
from skrf.media import device
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/oliver/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
dummy = rf.Network('50Ohm_dummy_load.s1p')
R_94R = rf.Network('94Ohm_resistors.s1p')
ww_100R = rf.Network('100Ohm_wire_wound_resistor.s1p')
ww_150R = rf.Network('150Ohm_wire_wound_resistor.s1p')
ww_200R = rf.Network('200Ohm_wire_wound_resistor.s1p')

# %%
plt.figure(figsize=(10,10))
dummy.s11.plot_s_smith(linewidth=3,label="50R dummy load")
R_94R.s11.plot_s_smith(linewidth=3,label="94R ceramic resistor")
ww_100R.s11.plot_s_smith(linewidth=3,label="100R wire wound resistor")
#ww_200R.s11.plot_s_smith(label="200R wire wound resistor")
